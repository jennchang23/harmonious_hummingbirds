# %%
import pandas as pd
import geopy.distance
import re

def is_inside_radius(t1, t2, radius):
    dist = geopy.distance.distance(t1, t2).mi
    if dist <= radius:
        return True
    return False

# df["inside"] = df.apply(lambda row: is_inside_radius(row["latitude"],row["longitude"],crime_data_df,10), axis=1)
# is_inside_radius((34.1016, -118.3962), (34.1016, -118.3964), 2)

# %%
is_inside_radius((34.1016, -118.3962), (34.1016, -118.3964), 2)

# %%
# !pip install geopy
# !pip install LinQ
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import postgis as pg
import re
from linq import Flow
# crime_data = "../Crime_Data_from_2010_to_2019.csv"
crime_data_df = pd.read_csv("Crime_Data_from_2010_to_2019.csv")
# !pip install Django==3.0.2
# from django.db import connection

# # from django.shortcuts import render_to_response
# # from models import CampSite
# from geopy import geocoders
# from django.contrib.gis.geos import *
# from django.contrib.gis.measure import D
# from campsites.forms import SearchForm
# from django.http import HttpResponseRedirect
# def results(request):
#     query = request.GET['q']
#     g = geocoders.Google(resource='maps')
#     location, (lat, lon) = g.geocode(query) 
#     pnt = fromstr("POINT(%s %s)" % (lon, lat))
#     distance_from_point = {'mi':'2000'}
#     results = CampSite.objects.filter(lonlat__distance_lte=(pnt,D(**distance_from_point))).distance(pnt).order_by('distance')
#     return render_to_response('results.html',{'location': location, 'lat': lat, 'lon': lon, 'results':results})
# find point around  
crime_data_df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA   \
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45     14
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515     13
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150      6
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100      1
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0     Newton         1385         2     900
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
# 4    Central          176         1     122
#
#                                          Crm Cd Desc  ... Status  \
# 0                           VIOLATION OF COURT ORDER  ...     AA
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# ...

# %%
lat = crime_data_df.loc[: , "LAT"]
lon = crime_data_df.loc[: , "LON"]

query= "SELECT ID, NOM, LAT, LON, 3956 * 2 * ASIN(SQRT(POWER(SIN((%s - LAT) * 0.0174532925 / 2), 2) + COS(%s * 0.0174532925) * COS(LAT * 0.0174532925) * POWER(SIN((%s - LON) * 0.0174532925 / 2), 2) )) as distance from POI  having distance < 50 ORDER BY distance ASC " % ( latitude, latitude, longitude)

# %%
is_inside_radius((34.1016, -118.3962), (34.1016, -118.3964), 2)
# Out:
# True

# %%
# !pip install geopy
from geopy import great_circle
import numpy as np

def dist_calc(point, list_of_points):
    dist = np.vectorize(lambda x: great_circle(point, x).meters)
    return dist(list_of_points)

# Now you can call it simply using:
crime_data_df['points'] = list(zip(crime_data_df['lat'], crime_data_df['lon']))
crime_data_df['distances'] = crime_data_df.groupby('vehicle')['points'].transform(dist_calc, point=incident_sw)
# Out:
# ...
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-28-c827b84c95fa> in <module>
#       1 get_ipython().system('pip install geopy')
# ----> 2 from geopy import great_circle
#       3 import numpy as np
#       4
#       5 def dist_calc(point, list_of_points):
#
# ImportError: cannot import name 'great_circle' from 'geopy' (C:\ProgramData\Anaconda3\lib\site-packages\geopy\__init__.py)

# %%
# cursor = connection.cursor()
# cursor.execute( query )
# rows = cursor.fetchall()

query= "SELECT ID, NOM, LAT, LON, 3956 * 2 * ASIN(SQRT(POWER(SIN((%s - LAT) * 0.0174532925 / 2), 2) + COS(%s * 0.0174532925) * COS(LAT * 0.0174532925) * POWER(SIN((%s - LON) * 0.0174532925 / 2), 2) )) as distance from POI  having distance < 50 ORDER BY distance ASC " % ( latitude, latitude, longitude)
